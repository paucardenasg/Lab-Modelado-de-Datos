# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# - <Strong> Paula Daniela Cárdenas Gallardo </Strong>
# - <Strong> Año </Strong>: 2021
# - <Strong> Email: </Strong>  <font color="blue"> `p.daniela.cardenas@gmail.com` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# **Aplicaciones de la vida real**
#
# - Control del vuelo de aviones
# - Control automotriz
# - Área médica
# - Optimizar el rendimiento del Wi-fi

# %%
from IPython.display import Image
Image(filename='compare_NN.JPG', width=600, height=400)

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %%
from IPython.display import Image
Image(filename='neuron_weights.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático de la neurona**
#
# $$\nu = w_{0}+w_{1}x_{1}+w_{2}x_{2}+w_{3}x_{3}+w_{4}x_{4}+w_{5}x_{5}$$
# $$y = \varphi(\nu)$$

# %%
from IPython.display import Image
Image(filename='capa_oculta.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático red neuronal**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# $$y^{2} = \varphi(\nu^{2})$$

# %%
from IPython.display import Image
Image(filename='capa_oculta2.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático usando dos capas oculta**
#
# <font color= #66CC00>$$\nu^{1} = w_{0}^{1}+w^{1}$$</font>
# <font color= #66CC00>$$y^{1} = \varphi(\nu^{1})$$</font>
# <font color= #009900>$$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$</font>
# <font color= #009900>$$y^{2} = \varphi(\nu^{2})$$</font>
# <font color= #3399FF>$$\nu^{3} = w_{0}^{3}+w^{3}y_{2}$$</font>
# <font color= #3399FF>$$y^{3} = \varphi(\nu^{3})$$</font>
#
#
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - Lineal: se recomienda para cuando el problema es sencillo
# - Sigmoidal: típicamente para problemas de clasificación. Sufre del problema de "Gradiente que se desvanece", los gradientes de la salida de la red con respecto a los parámetros se vuelven tan pequeños que la red neuronal da pasos más pequeños hacia los mínimos de la función de costo y finalmente deja de aprender.
# - Tanh: muy similar a la sigmoidal
# - RELU: es la más utilizada para capas ocultas. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Softmax: no se recomienda mucho usarla ya que el cálculo de gradientes no es tan eficiente
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
# **Backpropagation**
#
# Es el método que usa para ajustar el modelo. Minimiza el error medio cuadrático (MSE), utilizando el gradiente descendente para calcular los parámetros con el orden del último hacia el primero.
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# Se recomienda usar la regla de:
# (# capas ocultas = #entradas + # salidas)
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# Depende....
#
# De forma ideal, el número de neuronas ocultas debe ser mayor al número de entradas (#Neuronas ocultas > # variables de entrada).
#
# Peroooo esta regla tiene varias formas de verse afectada:
#
# 1. Número de datos
# 2. Poder computacional
#
# Si se tienen pocos datos, al aumentar el número de neuronas ocultas, la cantidad de pesos se empieza a ser comparable con las muestras que se tienen, entonces conviene aumentar la cantidad de neuronas ocultas.
#
# Si se tienen muchos datos, esta regla de (#Neuronas ocultas > # variables de entrada) no es fácil por cuestiones computacionales, por lo tanto usamos las siguientes reglas:
#
# - El número de neuronas ocultas debe estar entre el tamaño de la capa de entrada y el tamaño de la capa de salida.
# - El número de neuronas ocultas debe ser 2/3 del tamaño de la capa de entrada, más el tamaño de la capa de salida.
# - El número de neuronas ocultas es la media de las neuronas en las capas de entrada y salida.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

# %% [markdown]
# #### Ejemplo de una sola variable (X)

# %%
# Generamos datos
# Generar la X
m = 1000;
X = np.linspace(-1,1,num=m)
X = np.reshape(X,(m,1))

# Generar la Y
Y = 2*X**3+2*X**2 

[m,ne] = np.shape(X)

from sklearn import preprocessing
X = preprocessing.scale(X)
Y = preprocessing.scale(Y)

# Graficar los datos
fig = plt.figure()
plt.plot(X,Y, linewidth=3)
plt.grid()

# %%
# Dividir los datos en test y train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size= 0.2, random_state= 42)

# %%
# Diseño del modelo
# Inicializar objeto
model = Sequential()

# Agregar capas
# Agregar la primera capa de entrada
# Capa densa significa que todas las neuronas anteriores van con todas las que siguen
# Elegir 5 neuronas en esa capa
# input_dim = 1 porque tenemos solo una X. Aquí nos preguntamos: ¿cuántas entradas voy a tener?
model.add(Dense(5, activation='relu', input_dim=1,name='input_layer'))


# Para añadir capas ocultas
#model.add(Dense(10, activation='tanh', name='hidden_layer'))

# Agregar la capa de salida, debe ser lineal
model.add(Dense(1, activation='linear',name='output_layer'))


# Gradiente descendente
# épocas = cuántas veces se repite el gradiente descendente para encontrar el mínimo del MSE
# si la funcion de costo J tiene muchos picos, se recomienda disminuir el decaimineto o aumentar la tasa de aprendizaje
# Momentum: Utiliza la ley física del movimiento para atravesar óptimos locales (pequeñas colinas). 
# agrega un impulso que hará que la convergencia sea más rápida
learning_rate=0.1
epochs = 200
momentum = 0.8
decay_rate = learning_rate/epochs
sgd = SGD(lr=learning_rate, decay=decay_rate, momentum=momentum)

model.compile(loss='mean_squared_error',
              optimizer=sgd, 
             metrics = ['mse'])
# Out:
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
# Ajustar el modelo
history = model.fit(X_train, y_train, 
                   epochs=epochs, 
                   batch_size=100, 
                   validation_data=(X_test,y_test))
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 81ms/step - loss: 0.5023 - mse: 0.5023 - val_loss: 0.2285 - val_mse: 0.2285
# Epoch 2/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1239 - mse: 0.1239 - val_loss: 0.0507 - val_mse: 0.0507
# Epoch 3/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0339 - val_mse: 0.0339
# Epoch 4/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0253 - mse: 0.0253 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 5/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 6/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 7/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 8/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 9/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 10/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 11/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 12/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 13/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 14/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 17/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 18/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 19/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 20/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 21/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 22/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 23/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 24/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 25/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 26/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 27/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 28/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 30/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 34/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 35/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 36/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 37/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 38/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 39/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 40/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 41/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 42/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 45/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 46/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 47/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 48/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 49/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 50/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 51/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 52/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 53/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 54/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 55/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 56/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 57/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 58/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 59/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 60/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 61/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 62/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 63/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 64/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 65/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 66/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 67/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 68/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 69/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 70/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 71/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 72/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 73/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 74/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 75/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 76/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 77/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 78/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 79/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 80/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 81/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 82/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 83/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 84/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 85/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 86/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 87/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 88/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 89/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 90/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 91/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 92/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 93/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 94/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 95/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 96/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 97/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 98/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 99/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 100/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 101/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 102/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 103/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 104/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 105/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 106/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 107/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 108/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 109/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 110/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 111/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 112/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 113/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 114/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 115/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 116/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 117/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 118/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 119/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 120/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 121/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 122/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 123/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 124/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 125/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 126/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 127/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 128/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 129/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 130/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 131/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 132/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 133/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 134/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 135/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 136/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 137/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 138/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 139/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 140/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 141/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 142/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 143/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 144/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 145/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 146/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 147/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 148/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 149/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 150/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 151/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 152/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 153/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 154/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 155/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 156/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 157/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 158/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 159/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 160/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 161/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 162/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 163/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 164/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 165/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 166/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 167/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 168/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 169/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 170/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 171/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 172/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 173/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 174/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 175/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 176/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 177/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 178/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 179/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 180/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 181/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 182/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 183/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 184/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 185/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 186/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 187/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 188/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 189/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 190/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 191/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 192/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 193/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 194/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 195/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 196/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 197/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 198/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 199/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 200/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0047 - val_mse: 0.0047

# %%
# Graficar el MSE
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
# Evaluación del modelo
# Evaluación del modelo en los datos de prueba
score = model.evaluate(X_test,y_test)
print('Test mse:', score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0047 - mse: 0.0047
# Test mse: 0.004724267404526472

# %%
# Predicción  y calcular R2
# Con datos del test
yhat = model.predict(X_test)
R2_score = r2_score(y_test,yhat)
xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()

# %%
print('R2:', R2_score)
# Out:
# R2: 0.9956313837395323

# %% [markdown]
# #### Ejemplo Multivariable (Más de una variable de entrada X)

# %%
m = 100;
X = np.linspace(-1,1,num=m)
[x1,x2] = np.meshgrid(X,X)
X = np.c_[x1.ravel(),x2.ravel()]
Y = X[:,0]**2+X[:,1]**2

# %%
np.shape(X)
# Out:
# (10000, 2)

# %%
[m,ne] = np.shape(X)
print([m,ne])
# Out:
# [10000, 2]

# %%
np.shape(Y)
# Out:
# (10000,)

# %%
Y= np.reshape(Y,(m,1))

# %%
np.shape(Y)
# Out:
# (10000, 1)

# %%
from sklearn import preprocessing
X = preprocessing.scale(X)
Y = preprocessing.scale(Y)

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

plt.show()

# %%
#Dividimos los datos en test y train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2, random_state=42)

# %%
# Diseño del modelo

#Inicializo objeto
model = Sequential()

#Agregar capas

#Agregamos la primera capa de entrada
model.add(Dense(5, activation='relu', input_dim=2,name='input_layer')) #tanh
#Si quisiera añadir una capa oculta extra
#model.add(Dense(10, activation='tanh', name='hidden_layer'))
#Agregamos la capa de salida
model.add(Dense(1, activation='linear',name='output_layer'))

epochs = 200
momentum = 0.8
decay_rate = learning_rate/epochs
sgd = SGD(lr=learning_rate, decay=decay_rate, momentum=momentum)
model.compile(loss='mean_squared_error',
              optimizer=sgd, 
             metrics = ['mse'])
# Out:
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
#Ajustamos el modelo
history = model.fit(X_train, y_train, 
                   epochs=epochs, 
                   batch_size=100, 
                   validation_data=(X_test,y_test))
# Out:
# Epoch 1/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.4034 - mse: 0.4034 - val_loss: 0.0703 - val_mse: 0.0703
# Epoch 2/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0672 - mse: 0.0672 - val_loss: 0.0619 - val_mse: 0.0619
# Epoch 3/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 4/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0651 - mse: 0.0651 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 5/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0621 - mse: 0.0621 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 6/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 7/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0602 - val_mse: 0.0602
# Epoch 8/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0616 - mse: 0.0616 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 9/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0619 - mse: 0.0619 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 10/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0608 - val_mse: 0.0608
# Epoch 11/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0611 - mse: 0.0611 - val_loss: 0.0628 - val_mse: 0.0628
# Epoch 12/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0613 - mse: 0.0613 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 13/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0609 - mse: 0.0609 - val_loss: 0.0610 - val_mse: 0.0610
# Epoch 14/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 15/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 16/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0622 - mse: 0.0622 - val_loss: 0.0645 - val_mse: 0.0645
# Epoch 17/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0618 - mse: 0.0618 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 18/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0654 - val_mse: 0.0654
# Epoch 19/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0627 - mse: 0.0627 - val_loss: 0.0613 - val_mse: 0.0613
# Epoch 20/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 21/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0609 - val_mse: 0.0609
# Epoch 22/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0617 - mse: 0.0617 - val_loss: 0.0635 - val_mse: 0.0635
# Epoch 23/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 24/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 25/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 26/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0605 - mse: 0.0605 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 27/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 28/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 29/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0600 - mse: 0.0600 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 30/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 31/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0601 - mse: 0.0601 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 32/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0600 - mse: 0.0600 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 33/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 34/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0601 - mse: 0.0601 - val_loss: 0.0621 - val_mse: 0.0621
# Epoch 35/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0606 - val_mse: 0.0606
# Epoch 36/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0604 - mse: 0.0604 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 37/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 38/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0601 - mse: 0.0601 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 39/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0606 - mse: 0.0606 - val_loss: 0.0585 - val_mse: 0.0585
# Epoch 40/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0601 - mse: 0.0601 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 41/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 42/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0596 - mse: 0.0596 - val_loss: 0.0603 - val_mse: 0.0603
# Epoch 43/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 44/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0600 - mse: 0.0600 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 45/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0601 - mse: 0.0601 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 46/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 47/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 48/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0608 - val_mse: 0.0608
# Epoch 49/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 50/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0600 - mse: 0.0600 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 51/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0585 - val_mse: 0.0585
# Epoch 52/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 53/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 54/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 55/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 56/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 57/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 58/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0596 - mse: 0.0596 - val_loss: 0.0608 - val_mse: 0.0608
# Epoch 59/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0596 - mse: 0.0596 - val_loss: 0.0612 - val_mse: 0.0612
# Epoch 60/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 61/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 62/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 63/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0596 - mse: 0.0596 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 64/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 65/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0585 - val_mse: 0.0585
# Epoch 66/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 67/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0573 - val_mse: 0.0573
# Epoch 68/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 69/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 70/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 71/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 72/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 73/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 74/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0596 - mse: 0.0596 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 75/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 76/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 77/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0610 - val_mse: 0.0610
# Epoch 78/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 79/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 80/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 81/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 82/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 83/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 84/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 85/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 86/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0596 - mse: 0.0596 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 87/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 88/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 89/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 90/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 91/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 92/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 93/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 94/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 95/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 96/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 97/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 98/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 99/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 100/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 101/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 102/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 103/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 104/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 105/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 106/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 107/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 108/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 109/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 110/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 111/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 112/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 113/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 114/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 115/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 116/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0603 - val_mse: 0.0603
# Epoch 117/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 118/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 119/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 120/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 121/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 122/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 123/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 124/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 125/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 126/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 127/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 128/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 129/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 130/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 131/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 132/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 133/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 134/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 135/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 136/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 137/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 138/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 139/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 140/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 141/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 142/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 143/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 144/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 145/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 146/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 147/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 148/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 149/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 150/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 151/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 152/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 153/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 154/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 155/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 156/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 157/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 158/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 159/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 160/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 161/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 162/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 163/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 164/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 165/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 166/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 167/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 168/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 169/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 170/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 171/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 172/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 173/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 174/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 175/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 176/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 177/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 178/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 179/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 180/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0574 - val_mse: 0.0574
# Epoch 181/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 182/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0574 - val_mse: 0.0574
# Epoch 183/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 184/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 185/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 186/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 187/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 188/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 189/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 190/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 191/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 192/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 193/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0585 - val_mse: 0.0585
# Epoch 194/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 195/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 196/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 197/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 198/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 199/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 200/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0574 - val_mse: 0.0574

# %%
# Graficar el MSE
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
# Evaluación del modelo

# Evaluación del modelo en los datos de prueba
score = model.evaluate(X_test,y_test)
print('Test mse:', score[1])
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0574 - mse: 0.0574
# Test mse: 0.05741330236196518

# %%
# Predicción  y calcular R2

# Con datos del test
yhat = model.predict(X_test)
R2_score = r2_score(y_test,yhat)
xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()

# %%
print('R2:', R2_score)
# Out:
# R2: 0.9419785962655343

# %% [markdown]
# #### Ejemplo Cross Validation

# %%
# Cross Validation
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score

# %%
# Crear función que regresa una red neuronal compilada
import tensorflow
def create_network():
    
    # Iniciar objeto de red neuronal
    network = Sequential()

    # Añadir una capa de entrada
    network.add(Dense(5, activation='tanh', input_dim=2,name='input_layer')) #Relu

    # Añadir capa oculta
    #network.add(Dense(10, activation='relu')) #tanh

    # Añadir capa de salida
    network.add(Dense(1, activation='linear'))
    
    opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
                           decay=decay_rate)
    
    # Compilar la red neuronal
    network.compile(loss= 'mean_squared_error', 
                    optimizer= opt, 
                    metrics= ['mse']) 
    
    #regresa la red compilada
    return network

# %%
# Hacer el modelo en keras para que pueda ser usado por scikit-learn
neural_network= KerasRegressor(build_fn=create_network, 
                                 epochs=200, 
                                 batch_size=100, 
                                 verbose=0)

# %%
# Evaluar la red neuronal usando 10-fold cross-validation
print('MSE:', (-cross_val_score(neural_network, X, Y, cv=10,  scoring='neg_mean_squared_error')).mean())
# Out:
# MSE: nan
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %%
print('R2:', (cross_val_score(neural_network, X, Y, cv=10,  scoring='r2')).mean())
# Out:
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# R2: nan
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daniela Cardenas\Anaconda Navigator\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-29-02c8d218e84e>", line 17, in create_network
#     opt = tensorflow.keras.optimizers.SDG(lr=learning_rate,momentum=momentum,
# AttributeError: module 'tensorflow.keras.optimizers' has no attribute 'SDG'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %% [markdown]
# ### Optimización de hiperparámetros
#
# **GridSearch**
#
# ![GridSearch](https://www.yourdatateacher.com/wp-content/uploads/2021/03/image-7.png)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score,mean_squared_error,make_scorer

# %% [markdown]
# ### Ventajas y desventajas de las redes neuronales
#
# #### Ventajas
#
# - Capacidad de trabajar con información incompleta
# - Si algo llega a fallar en una neurona, se pueden aún obtener resultados - Tolerantes a fallas
# - Tienen la capacidad de aprender por sí mismas y generar resultados que no se limitan a la información que se les dió al principio.
# - Capacidad de procesamiento en paralelo
# - Autoorganización: la capacidad de agrupar y clasificar grandes cantidades de datos hace que las redes neuronales sean especialmente adecuadas para organizar los complicados problemas visuales que plantea el análisis de imágenes
#
# #### Desventajas
#
# - Debido a su naturaleza de "caja negra" se pierde interpretación del modelo
# - Usualmente requieren muchos más datos que los modelos tradicionales
# - Si hay demasiados datos, la red neuronal requiere procesadores con gran poder de procesamiento
# - No hay regla específica para determinar la estructura de la red - Prueba y error
# - Pueden llegar a convertirse muy complejas

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
